# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 1 ) 그래프 기본

# %%
x = [1,2,3]
y = [2,4,8]
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# # Title 설정

# %%
plt.plot(x,y)
plt.title('Line Graph') # 제목 붙이기
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x,y)
plt.title("꺾은선 그래프")
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')
# /Users/jiseungmin/miniforge3/envs/tf/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44734 (\N{HANGUL SYLLABLE GGEOGG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/jiseungmin/miniforge3/envs/tf/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/jiseungmin/miniforge3/envs/tf/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/jiseungmin/miniforge3/envs/tf/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/jiseungmin/miniforge3/envs/tf/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/jiseungmin/miniforge3/envs/tf/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # 한글 폰트 설정

# %%
import matplotlib
matplotlib.rcParams['font.family'] = "AppleGothic"
matplotlib.rcParams['font.size'] = 15
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용시 마이너스 깨짐 현상 해결

# %%
import matplotlib.font_manager as fm
fm.fontManager.ttflist
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['DejaVu Sans',
#  'STIXSizeOneSym',
#  'DejaVu Sans Mono',
#  'cmex10',
#  'DejaVu Sans',
#  'DejaVu Serif Display',
#  'STIXSizeTwoSym',
#  'STIXSizeFourSym',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'cmss10',
#  'DejaVu Sans Display',
#  'DejaVu Sans',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'STIXSizeThreeSym',
#  'cmb10',
#  'STIXGeneral',
#  'STIXSizeTwoSym',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'cmsy10',
#  'STIXGeneral',
#  'cmmi10',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'STIXSizeOneSym',
#  'STIXNonUnicode',
#  'cmr10',
#  'STIXNonUnicode',
#  'DejaVu Serif',
#  'cmtt10',
#  'DejaVu Serif',
#  'STIXSizeFiveSym',
#  'DejaVu Sans',
#  'Noto Sans Lycian',
#  'Comic Sans MS',
#  'Hiragino Sans',
#  'Academy Engraved LET',
#  'Hiragino Sans',
#  'Party LET',
#  'Didot',
#  '.SF Arabic',
#  'Arial',
#  'Kailasa',
#  'Hiragino Sans',
#  'Kannada Sangam MN',
#  'Al Bayan',
#  'Courier',
#  'Tamil Sangam MN',
#  'Noto Sans Pahawh Hmong',
#  'Beirut',
#  'Noto Sans Pau Cin Hau',
#  'STIXNonUnicode',
#  'Noto Sans Old Persian',
#  'Zapf Dingbats',
#  'Noto Sans Takri',
#  'Noto Sans Old Permic',
#  'Noto Sans Kaithi',
#  'Shree Devanagari 714',
#  'Noto Sans Meroitic',
#  'STIXGeneral',
#  'Andale Mono',
#  'Farisi',
#  'Lao Sangam MN',
#  'Noto Sans Meetei Mayek',
#  'Marker Felt',
#  'Wingdings',
#  'Bodoni 72 Oldstyle',
#  'Noto Sans Mahajani',
#  'Tamil MN',
#  'Kokonor',
#  'Telugu MN',
#  'Hiragino Sans',
#  'Noto Sans PhagsPa',
#  'STIXSizeThreeSym',
#  'Gujarati Sangam MN',
#  'Mshtakan',
#  'Noto Sans Buhid',
#  '.Aqua Kana',
#  'Verdana',
#  'Noto Sans Lepcha',
#  'STIXIntegralsUp',
#  'Noto Sans Tai Le',
#  'Geneva',
#  'Noto Sans Batak',
#  'Arial Narrow',
#  'Superclarendon',
#  'Times New Roman',
#  'Noto Sans Wancho',
#  'Noto Sans Sora Sompeng',
#  'Trebuchet MS',
#  'STIXIntegralsSm',
#  'Sukhumvit Set',
#  'Hiragino Sans',
#  'Hiragino Mincho ProN',
#  'Palatino',
#  'Hiragino Sans',
#  'Noto Sans Osage',
#  'Skia',
#  'Trebuchet MS',
#  'DecoType Naskh',
#  'Noto Sans Cuneiform',
#  'Noto Sans Ugaritic',
#  'Verdana',
#  'Bradley Hand',
#  'Noto Sans Armenian',
#  'Arial Unicode MS',
#  'Noto Sans Multani',
#  'Avenir Next Condensed',
#  'Noto Sans Oriya',
#  'Galvji',
#  '.SF Compact',
#  'Apple Braille',
#  'Krungthep',
#  'Georgia',
#  'Bodoni Ornaments',
#  'Arial',
#  'STIXSizeThreeSym',
#  'Hoefler Text',
#  'Noto Sans Coptic',
#  'Noto Sans Tagbanwa',
#  'Times New Roman',
#  'Noto Sans Limbu',
#  '.SF NS Mono',
#  'Noto Sans Chakma',
#  'Noto Sans Manichaean',
#  'Noto Sans Linear B',
#  'Hiragino Maru Gothic Pro',
#  'Noto Sans Linear A',
#  'Noto Sans Mongolian',
#  'Avenir',
#  '.SF NS Rounded',
#  '.New York',
#  'System Font',
#  'STIXSizeOneSym',
#  'DIN Alternate',
#  'Songti SC',
#  'Noto Sans Lydian',
#  'Noto Sans Inscriptional Pahlavi',
#  'PT Serif Caption',
#  'Mishafi',
#  'Gill Sans',
#  'Trebuchet MS',
#  'Noto Sans Tagalog',
#  'Hiragino Sans',
#  'PT Serif',
#  'Gujarati MT',
#  'Noto Sans Miao',
#  'Devanagari Sangam MN',
#  'Noto Sans Bhaiksuki',
#  'Noto Sans NKo',
#  'STIXIntegralsUp',
#  'Impact',
#  'Verdana',
#  'Hoefler Text',
#  'Noto Sans Ol Chiki',
#  'Apple Braille',
#  'Helvetica Neue',
#  'Oriya Sangam MN',
#  'Marion',
#  'Arial',
#  'Copperplate',
#  'STIXVariants',
#  'SignPainter',
#  'Trattatello',
#  'Noto Sans Sundanese',
#  'Noto Sans Vai',
#  'Farah',
#  'Courier New',
#  'Courier New',
#  'Noto Sans Saurashtra',
#  'Hiragino Sans',
#  'Noto Sans Old South Arabian',
#  'Diwan Thuluth',
#  'Noto Sans Kharoshthi',
#  'Arial',
#  'Geeza Pro',
#  'Noto Sans Duployan',
#  'Charter',
#  'American Typewriter',
#  'Kefa',
#  'Diwan Kufi',
#  'Kannada MN',
#  'Papyrus',
#  'Arial Narrow',
#  'Chalkboard',
#  'Gurmukhi Sangam MN',
#  'Myanmar Sangam MN',
#  'Apple Braille',
#  'Noto Sans Mandaic',
#  'Kohinoor Devanagari',
#  'Gurmukhi MN',
#  'Noto Sans Kannada',
#  'Myanmar MN',
#  'Noto Sans Cham',
#  'Sinhala MN',
#  'Gurmukhi MT',
#  'Times New Roman',
#  'Noto Sans Warang Citi',
#  'Futura',
#  'Noto Nastaliq Urdu',
#  'STIXIntegralsD',
#  'InaiMathi',
#  'Malayalam Sangam MN',
#  'Tahoma',
#  'Noto Sans Old Italic',
#  'Noto Sans Gunjala Gondi',
#  'Sinhala Sangam MN',
#  'Noto Sans Caucasian Albanian',
#  'Big Caslon',
#  'STIXSizeOneSym',
#  'Raanana',
#  'STIXIntegralsD',
#  'Symbol',
#  'Noto Sans New Tai Lue',
#  'STIXGeneral',
#  '.Keyboard',
#  'Noto Sans Egyptian Hieroglyphs',
#  'Noto Sans Nabataean',
#  'STIXVariants',
#  'Noto Sans Kayah Li',
#  'Noto Serif Myanmar',
#  'DIN Condensed',
#  'Lao MN',
#  'Noto Sans Samaritan',
#  'Verdana',
#  'Heiti TC',
#  'Herculanum',
#  'Tahoma',
#  'Noto Sans Mende Kikakui',
#  'Savoye LET',
#  'Ayuthaya',
#  'Wingdings 2',
#  'Noto Sans Glagolitic',
#  'Bangla MN',
#  'Lucida Grande',
#  'PingFang HK',
#  'Noto Sans Yi',
#  'Apple Braille',
#  'Noto Sans Lisu',
#  'Rockwell',
#  '.New York',
#  'Zapfino',
#  'Kohinoor Gujarati',
#  'Noto Sans Bamum',
#  'AppleGothic',
#  'Noto Sans Siddham',
#  'New Peninim MT',
#  'Baskerville',
#  'Noto Serif Yezidi',
#  'Times',
#  'Georgia',
#  'Noto Sans Newa',
#  'Noto Sans Thaana',
#  'Noto Sans Brahmi',
#  'STIXNonUnicode',
#  'Noto Sans Hanunoo',
#  'AppleMyungjo',
#  'STIXNonUnicode',
#  'ITF Devanagari',
#  'Noto Sans Imperial Aramaic',
#  'Arial Black',
#  'KufiStandardGK',
#  '.SF Compact Rounded',
#  'Noto Serif Balinese',
#  'Noto Sans Javanese',
#  'Brush Script MT',
#  'Sathu',
#  'Heiti TC',
#  'Seravek',
#  'Oriya MN',
#  'STIXIntegralsUpD',
#  'Courier New',
#  'STIXIntegralsSm',
#  'Phosphate',
#  'Monaco',
#  'Arial Rounded MT Bold',
#  'Noto Sans Modi',
#  'Noteworthy',
#  'Mishafi Gold',
#  'Kohinoor Bangla',
#  'Noto Sans Tai Viet',
#  'Noto Sans Syloti Nagri',
#  'Noto Sans Osmanya',
#  'STIXIntegralsUpD',
#  'Wingdings 3',
#  'Times New Roman',
#  'Apple Chancery',
#  'Noto Sans Mro',
#  'Cochin',
#  'Al Tarikh',
#  'Noto Sans Buginese',
#  'Chalkduster',
#  'STIXIntegralsUpSm',
#  'Noto Sans Tirhuta',
#  'Noto Sans Masaram Gondi',
#  'Noto Sans Inscriptional Parthian',
#  'Arial Unicode MS',
#  'Bodoni 72',
#  'Nadeem',
#  'Noto Sans Hatran',
#  'Athelas',
#  'Malayalam MN',
#  'Khmer Sangam MN',
#  'Arial Hebrew',
#  'Corsiva Hebrew',
#  'Noto Sans Gothic',
#  'Thonburi',
#  'Bodoni 72 Smallcaps',
#  'Plantagenet Cherokee',
#  'Euphemia UCAS',
#  'Noto Sans Psalter Pahlavi',
#  'Noto Sans Carian',
#  'Noto Sans Rejang',
#  'STIXSizeTwoSym',
#  'STIXSizeFiveSym',
#  'Arial Narrow',
#  'Noto Serif Ahom',
#  'Al Nile',
#  'Courier New',
#  'Muna',
#  'Bangla Sangam MN',
#  'PT Sans',
#  'Noto Sans Sharada',
#  'Hiragino Sans',
#  'Webdings',
#  'Waseem',
#  'Georgia',
#  'Luminari',
#  'Noto Sans Palmyrene',
#  'Iowan Old Style',
#  'STIXSizeFourSym',
#  'Noto Sans Adlam',
#  'Baghdad',
#  'STIXGeneral',
#  'Hiragino Sans GB',
#  'Mukta Mahee',
#  'Trebuchet MS',
#  'Telugu Sangam MN',
#  'Noto Sans Elbasan',
#  'Noto Sans Syriac',
#  'Microsoft Sans Serif',
#  'Silom',
#  'Chalkboard SE',
#  'System Font',
#  'Comic Sans MS',
#  '.SF Compact',
#  'Noto Sans Khudawadi',
#  'Noto Sans Avestan',
#  'Arial Narrow',
#  'Noto Sans Cypriot',
#  'Khmer MN',
#  'Kohinoor Telugu',
#  'Noto Sans Khojki',
#  'Apple Braille',
#  'Noto Sans Old Hungarian',
#  'Menlo',
#  'STIXIntegralsUpSm',
#  'PT Mono',
#  'STIXGeneral',
#  'Damascus',
#  'STIXSizeTwoSym',
#  'Helvetica',
#  '.SF NS Mono',
#  'Noto Sans Phoenician',
#  'Avenir Next',
#  'Noto Sans Hanifi Rohingya',
#  'Snell Roundhand',
#  'STIXNonUnicode',
#  'Hiragino Sans',
#  'Noto Sans Old North Arabian',
#  'Noto Sans Old Turkic',
#  'Noto Sans Tai Tham',
#  'Optima',
#  'Apple Symbols',
#  'Noto Sans Tifinagh',
#  'Devanagari MT',
#  'Sana',
#  'Apple SD Gothic Neo',
#  'Noto Sans Bassa Vah',
#  'Georgia',
#  'Noto Sans Myanmar',
#  'Noto Sans Marchen',
#  'STIXSizeFourSym']

# %%
plt.plot(x,y)
plt.title("꺾은선 그래프")
# Out:
# Text(0.5, 1.0, '꺾은선 그래프')

# %%
plt.plot([-1,0,1],[-5,-1,2])
